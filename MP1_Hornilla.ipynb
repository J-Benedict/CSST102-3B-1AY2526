# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix



df=pd.read_csv("/content/sample_data/iris_dataset.csv")
print(df.head(5))

print(df.info)
print(df.describe())
print(df['species'].value_counts())

df['sepal length (cm)'].hist()
plt.title("Sepal Lenght Distribution")
plt.show()

sns.scatterplot(data=df,x="petal length (cm)",y='petal width (cm)',hue="species")
plt.title("Petal Length vs Width by Species")
plt.show()

#Features and target
x= df.drop('species',axis=1)
y=df['species']

#train-test split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#train decision tree
clf = DecisionTreeClassifier(random_state=42)
clf.fit(x_train,y_train)

#make predictions
y_pred=clf.predict(x_test)

#accuracy
print("Accuracy: ", accuracy_score(y_test,y_pred))

#confusion matrix
print("Confusion Matrix: \n", confusion_matrix(y_test,y_pred))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# <bound method DataFrame.info of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# ...

# %% [markdown]
# Hour 1 Mini-Task:
# 1. What is the input (features)?
#     The input is the iris_dataset.csv, where the ML gets its dataset
# 2. What is the output (label)?
#     The output is the length distribution and the length vs width by species.
# 3. Is this supervised or unsupervised learning?
#     Supervised learning as the ML model can only train itself on the given dataset
#
# Hour 2 Mini-Task:
# 1. Students compute model accuracy.
#     model accuracy is 1
#
# Hour 3 Mini-Task:
# 1. “What would happen if the dataset had missing or wrong values?”
#       The ML model will encounter problems when training
# 2. “How does this relate to real-world ML applications?”
#       When training real-world ML applications they are trained from using user input throughtout many years and they are trained with specific inputs to base on.
#
# Short Reflection:
# 1. What type of ML did you use?
#     The type of ML model is classification model wherein the ML model train itself using labeled data from a given dataset to classify the given data. The data mostly consist of flower species, petal length, and petal width. the output mostly shows the ML model seperating and classifying each data to its appropriate classification.
#
# 2. What challenge might affect the model?
#     A problem the ML model may encounter will be when there is unlabeled data or missing data in the dataset the model is given to train itself. Another problem with datasets will be insufficient data, non-representative data, or biased data that will affect the accuracy of the ML model. If the ML model is lacking any sort of maintenance and monitoring, the ML model may become buggy or function improperly.
